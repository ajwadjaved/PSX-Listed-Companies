# %%
import time
import pandas as pd
import requests
import urllib
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
# chromedriver = "chromedriver.exe"
# driver = webdriver.Chrome(chromedriver)
# driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")

# url = "https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies"
# response = requests.get(url)
# soup = BeautifulSoup(response.content, 'html.parser')

#     response = requests.get(url)
#     soup = BeautifulSoup(response.content, 'html.parser')
#     print(soup.select("tbody[id*=SectorviseSearch]"))
# elem = table[index].text
# print(elem.get_attribute(id))

# %%
# select = Select(driver.find_element_by_id("sector"))
# options = select.options
# listComp = pd.DataFrame()
# for idx, val in enumerate(options):
#     if idx == 0 or val.text == "Future contracts":
#         continue
#     select.select_by_index(idx)
#     time.sleep(2)
#     df = pd.read_html(driver.page_source)[0]
# #     print(idx, len(df), val.text)
#     df['Sector'] = val.text
#     listComp=listComp.append(df)

# driver.close()
# listComp = listComp.reset_index(drop=True)    
# listComp.to_csv("PSX_ListedCompaniesData.csv")

# # <tbody id="addressbookdata">
# listComp

# %%
chromedriver = "chromedriver.exe"
driver = webdriver.Chrome(chromedriver)
driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
driver.maximize_window()
df = []

select = Select(driver.find_element_by_id("sector"))

for opt in select.options[1:]: #skip first entry of for loop
    opt.click() #website has updated here
#     table = driver.find_elements_by_class_name("addressbook")
    
#     table = driver.find_element_by_xpath("//div[@class='addressbook' and style='cursor:pointer']")
#     table = driver.find_element_by_xpath("//div[@class='addressbook'][@style='cursor:pointer;']")
#     table = driver.find_element_by_xpath('//*[@class="SectorviseSearch"]')    
    table = driver.find_element_by_xpath('//*[@class="table-responsive"]')

#     df += [table.text]
    print(table.text)


#     for index in range(len(table)):
#         elem = table[index].text
#         print(elem)

# #             if index % 2 == 0:
        
#         elem = table[index].text
# #         print(elem)
# #             elem.click()
# #             data = driver.find_elements_by_class_name("addressbookdata")
# #             print(data)

driver.close()

# %%
import time
import pandas as pd
import requests
import urllib
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

df = pd.read_excel("data.xlsx", index_col=0)

numberoflines = [11,10,33,8,24,28,6,20,20,6,7,25,11,30,35,2,9,6,24,30,4,10,10,13,17,1,4,15,29,10,15,56,63,7,4,1]
addition = 0

# for x in numberoflines:
#     for i in range(x):
#         print(i)
# #         print(df['Ticker'][addition+i])

# #     addition += x
    
# for x in numberoflines:
#     for i in range(x):
#         symbol = df['Ticker'][addition+i] #this is symbol
#         print(symbol)

df['Ticker'][0:12]
# Out:
# Index
# 0                                        AGTL
# 1                                        ATLH
# 2                                        DFML
# 3                                        GHNI
# 4                                        GHNL
# 5                                        HCAR
# 6                                        HINO
# 7                                        INDU
# 8                                         MTL
# 9                                        PSMC
# 10        SAZEW Sazgar Engineering Works Ltd.
# 11    SAZEWR Sazgar Engineering Works Ltd.(R)
# Name: Ticker, dtype: object

# %%
# df = pd.read_excel("data.xlsx", index_col=0)
# df['Ticker'].iloc[252]

chromedriver = "chromedriver.exe"
driver = webdriver.Chrome(chromedriver)
driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
driver.maximize_window()
wait = WebDriverWait(driver, 30)

numoflines = [12,10,8,24,28,6,20,20,6,7,25,11,30,35,2,8,6,24,30,4,10,10,13,17,1,4,29,10,14,56,63,10,3,7,4,1]
df = pd.read_excel("data.xlsx", index_col=0)
addition = 0
index = 1 #to loop over list
sector = Select(driver.find_element_by_id("sector"))

for sec in sector.options[1:]:

#     if sec.text == "Bonds" or sec.text == "Stock index future contracts" or sec.text == "Future contracts":
#         continue 
    
    print("Index {}, Company Name {} ".format(index, sec.text))
    index += 1
# Out:
# C:\Users\ajwad\AppData\Local\Temp/ipykernel_1892/2406409272.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)
# C:\Users\ajwad\AppData\Local\Temp/ipykernel_1892/2406409272.py:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   sector = Select(driver.find_element_by_id("sector"))
# Index 1, Company Name Automobile assembler
# Index 2, Company Name Automobile parts & accessories
# Index 3, Company Name Bonds
# Index 4, Company Name Cable & electrical goods
# Index 5, Company Name Cement
# Index 6, Company Name Chemical
# Index 7, Company Name Close - end mutual fund
# Index 8, Company Name Commercial banks
# Index 9, Company Name Engineering
# Index 10, Company Name Exchange traded funds
# Index 11, Company Name Fertilizer
# Index 12, Company Name Food & personal care products
# Index 13, Company Name Future contracts
# ...

# %%
#TESTING 

chromedriver = "chromedriver.exe"
driver = webdriver.Chrome(chromedriver)
driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
driver.maximize_window()
wait = WebDriverWait(driver, 30)

# numoflines = [56,63,10,3,7,4,1]
numoflines = [12,10,8,24,28,6,20,20,6,7,25,11,30,35,2,8,6,24,30,4,10,10,13,17,1,4,29,10,15,56,63,10,3,7,4,1]

df = pd.read_excel("data.xlsx", index_col=0)
# addition = 425+15
addition = 0
index = 0 #to loop over list
sector = Select(driver.find_element_by_id("sector"))

with open("textilecomposite.txt", "w") as myfile:
    for sec in sector.options[1:]:
                  
        if sec.text == "Bonds" or sec.text == "Stock index future contracts" or sec.text == "Future contracts":
            continue        
    
        sec.click()
        loop = numoflines[index]

        for i in range(loop):
            symbol = df['Ticker'][addition+i] 
            symbol = str(symbol).split()[0] #picks up symbol
            print(symbol)
            
            findelement = wait.until(EC.presence_of_element_located((By.ID, symbol)))
            findelement.click()

            # we do this after thingy has been clicked upon
            extract = wait.until(EC.presence_of_element_located((By.ID, "addressbookdata")))

            #close the popup
            WebDriverWait(driver, 30).until(EC.element_to_be_clickable((By.XPATH, "//button[@class='close'][@data-dismiss='modal']"))).click()

            driver.execute_script("window.scrollBy(0,45);") #scroll down

            myfile.write(extract.get_attribute('innerText'))

        addition += loop
        index += 1
        driver.execute_script("window.scrollTo(0,0)")
# Out:
# C:\Users\ajwad\AppData\Local\Temp/ipykernel_1892/2573882430.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)
# C:\Users\ajwad\AppData\Local\Temp/ipykernel_1892/2573882430.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   sector = Select(driver.find_element_by_id("sector"))
# AGTL
# ATLH
# DFML
# GHNI
# GHNL
# HCAR
# HINO
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1892/2573882430.py in <module>
#      31
#      32             findelement = wait.until(EC.presence_of_element_located((By.ID, symbol)))
# ---> 33             findelement.click()
#      34
#      35             # we do this after thingy has been clicked upon
#
# ...

# %%
chromedriver = "chromedriver.exe"
driver = webdriver.Chrome(chromedriver)
driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
driver.maximize_window()
wait = WebDriverWait(driver, 30)

numoflines = [12,10,8,24,28,6,20,20,6,7,25,11,30,35,2,8,6,24,30,4,10,10,13,17,1,4,29,10,14,56,63,10,3,7,4,1]
df = pd.read_excel("data.xlsx", index_col=0)
addition = 0
index = 0 #to loop over list
sector = Select(driver.find_element_by_id("sector"))

with open("output.txt", "w") as myfile:
    for sec in sector.options[1:]:
                  
        if sec.text == "Bonds" or sec.text == "Stock index future contracts" or sec.text == "Future contracts":
            continue        
    
        sec.click()
        loop = numoflines[index]

        for i in range(loop):
            symbol = df['Ticker'][addition+i] 
            symbol = str(symbol).split()[0] #picks up symbol
            print(symbol)
            
            findelement = wait.until(EC.presence_of_element_located((By.ID, symbol)))
            findelement.click()

            # we do this after thingy has been clicked upon
            extract = wait.until(EC.presence_of_element_located((By.ID, "addressbookdata")))

            #close the popup
            WebDriverWait(driver, 30).until(EC.element_to_be_clickable((By.XPATH, "//button[@class='close'][@data-dismiss='modal']"))).click()

            driver.execute_script("window.scrollBy(0,50);") #scroll down

            myfile.write(extract.get_attribute('innerText'))

        addition += loop
        index += 1
        driver.execute_script("window.scrollTo(0,0)")
# Out:
# C:\Users\ajwad\AppData\Local\Temp/ipykernel_13576/2192987436.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(chromedriver)
# C:\Users\ajwad\AppData\Local\Temp/ipykernel_13576/2192987436.py:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   sector = Select(driver.find_element_by_id("sector"))
# AGTL
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13576/2192987436.py in <module>
#      25             print(symbol)
#      26
# ---> 27             findelement = wait.until(EC.presence_of_element_located((By.ID, symbol)))
#      28             findelement.click()
#      29
#
# c:\users\ajwad\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\support\wait.py in until(self, method, message)
# ...

# %%
sum([12,10,8,24,28,6,20,20,6,7,25,11,30,35,2,8,6,24,30,4,10,10,13,17,1,4,29,10,])
# Out:
# 410

# %%
chromedriver = "chromedriver.exe"
driver = webdriver.Chrome(chromedriver)
driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
driver.maximize_window()

sector = Select(driver.find_element_by_id("sector"))
symbol = Select(driver.find_element_by_id("Symbol"))


for sec in sector.options[1:]:
    sec.click()
    for sym in symbol.options:
        #table = sym.text
        if sym in df['Ticker'].values:
            wait = WebDriverWait(driver, 30)
            table = wait.until(EC.presence_of_element_located((By.ID, "addressbookdata"))).get_attribute('innerText')


            

        
#         for x in range(len(df)):
#             if df['Ticker'][x] == table:
#         wait = WebDriverWait(driver, 30)
#         print(wait.until(EC.presence_of_element_located((By.ID, "addressbookdata"))).get_attribute('innerText'))

driver.close()

# %%
table

# %%
#THIS CODE WORKS FOR SINGLE TICKER, JUST NEED TO SCALE

chromedriver = "chromedriver.exe"
driver = webdriver.Chrome(chromedriver)
driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
driver.maximize_window()

sector = Select(driver.find_element_by_id("sector"))
symbol = Select(driver.find_element_by_id("Symbol"))

for sec in sector.options[1:]:
    sec.click()
    
    for sym in symbol.options[1:]:
        table = sym.text
        
        wait = WebDriverWait(driver,30)
        findelement = wait.until(EC.presence_of_element_located((By.ID, table)))
        findelement.click()
        
        # we do this after thingy has been clicked upon
        wait = WebDriverWait(driver,30)
        extract = wait.until(EC.presence_of_element_located((By.ID, "addressbookdata")))

        #close the popup
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//button[@class='close'][@data-dismiss='modal']"))).click()

        with open("output.txt", "a") as myfile:
            myfile.write(extract.get_attribute('innerText'))
    
    
driver.quit()

# %%
# chromedriver = "chromedriver.exe"
# driver = webdriver.Chrome(chromedriver)
# driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
# driver.maximize_window()

# sector = Select(driver.find_element_by_id("sector"))
# symbol = Select(driver.find_element_by_id("Symbol"))


# for sec in sector.options[1:]:
#     sec.click()
#     for sym in symbol.options:
#         continue
# time.sleep(1)

# %%
df

# %%
chromedriver = "chromedriver.exe"
driver = webdriver.Chrome(chromedriver)
driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
driver.maximize_window()

sector = Select(driver.find_element_by_id("sector"))
symbol = Select(driver.find_element_by_id("Symbol"))


sec = sector.options[1]
sec.click()

# find_company = Select(driver.find_element_by_id({})).format(sym)
# print(find_company)

# findelement = driver.find_element_by_id("AGTL")

# findelement = Select(driver.find_element_by_id("AGTL"))
wait = WebDriverWait(driver,30)

findelement = wait.until(EC.presence_of_element_located((By.ID, "ATLH")))
findelement.click()

#close the popup
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//button[@class='close'][@data-dismiss='modal']"))).click()

findelement = wait.until(EC.presence_of_element_located((By.ID, "DFML")))
findelement.click()



# we do this after thingy has been clicked upon
wait = WebDriverWait(driver,30)
extract = wait.until(EC.presence_of_element_located((By.ID, "addressbookdata")))
# extract = Select(driver.find_element_by_id("addressbookdata")).get_attribute('innerText')

# text = extract.get_attribute('innerText')

with open("output.txt", "a") as myfile:
    myfile.write(extract.get_attribute('innerText'))
    
#         for x in range(len(df)):
#             if df['Ticker'][x] == table:

# %%
# chromedriver = "chromedriver.exe"
# driver = webdriver.Chrome(chromedriver)
# driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
# driver.maximize_window()

# sector = Select(driver.find_element_by_id("sector"))
# symbol = Select(driver.find_element_by_id("Symbol"))


# for sec in sector.options[1:]:
#     sec.click()
#     for sym in symbol.options:
#         table = sym.text
#         for x in range(len(df)):
#             if df['Ticker'][x] == table:
# #                 driver.find_element_by_xpath("//span[.='AGTL']").click();
# #                 button = driver.find_element_by_class ("//*span[contains( text( ), ‘AGTL’)]").click()
# #                 extraction = driver.find_elements_by_class_name("SectorviseSearch")

#                 element1 = find_element_by_css_selector('span:contains("View All Companies")')

#                 element1 = find_element_by_xpath('//span[contains(text(), df]')

#                 print(extraction)
#                 time.sleep(5)

# driver.quit()

# %%
#         for x in range(len(df)):
#             if df['Ticker'][x] == table:

# %%
#                 driver.find_element_by_xpath("//span[.='AGTL']").click();
#                 button = driver.find_element_by_class ("//*span[contains( text( ), ‘AGTL’)]").click()
#                 extraction = driver.find_elements_by_class_name("SectorviseSearch")

#                 element1 = find_element_by_css_selector('span:contains("View All Companies")')

#                 element1 = find_element_by_xpath('//span[contains(text(), df]')

# %%
# chromedriver = "chromedriver.exe"
# driver = webdriver.Chrome(chromedriver)
# driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
# driver.maximize_window()

# f = open('listed_companies.txt','a+')

# wait = WebDriverWait(driver, 30)
# driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")

# sector = Select(wait.until(EC.visibility_of_element_located((By.ID, "sector"))))
# symbol = Select(wait.until(EC.visibility_of_element_located((By.ID, "Symbol"))))

# allSectorOptions = sector.options
# for sector_ in allSectorOptions:
#     if sector_.get_attribute('value') != "0":
#         print("Inside sector loop")
#         sector_.click();
#         time.sleep(5)
#         print("Selected sector:", sector_.text)
#         allSymbolOptions = symbol.options
#         for symbol_ in allSymbolOptions:
#             if symbol_.get_attribute('value') != "0":
#                 print("Inside symbol loop")
#                 attempts = 0
#                 while attempts < 3:
#                     try:
#                         symbol_.click()
#                         break
#                     except StaleElementReferenceException as stale:
#                         print(stale.msg)
#                     attempts = attempts + 1
#                 print("Selected symbol:", symbol_.text)
#                 try:
#                     address_data = wait.until(EC.visibility_of_element_located((By.ID, "addressbookdata")))
#                     print(address_data.get_attribute('innerText'))
# #                     with open("output.txt", "a") as myfile:
# #                         myfile.write(extract.get_attribute('innerText'))
#                     print(address_data.get_attribute('innerText'))
#                     f.write(address_data.get_attribute('innerText'))
#                     wait.until(EC.element_to_be_clickable((By.XPATH, "//button[@class='close'][@data-dismiss='modal']"))).click()
#                 except:
#                     print("addressbookdata could not found for", symbol_.text)

# %%
# for sec in sector.options[1:]:
#     sec.click()
    
#     for sym in symbol.options[1:]:
#         table = sym.text
        
#         wait = WebDriverWait(driver,30)
#         findelement = wait.until(EC.presence_of_element_located((By.ID, table)))
#         findelement.click()
        
#         # we do this after thingy has been clicked upon
#         wait = WebDriverWait(driver,30)
#         extract = wait.until(EC.presence_of_element_located((By.ID, "addressbookdata")))

#         #close the popup
#         WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//button[@class='close'][@data-dismiss='modal']"))).click()

#         with open("output.txt", "a") as myfile:
#             myfile.write(extract.get_attribute('innerText'))
            
            
#     print(symbol.get_attribute('innerText'))
#     symbol = Select(wait.until(EC.visibility_of_element_located((By.ID, "Symbol"))))
#     for x in df['Ticker']:
#         table = False
#         table = wait.until(EC.presence_of_element_located((By.ID, x))).get_attribute('innerText')
#         if table is True:
#             print(table)

# %%
# chromedriver = "chromedriver.exe"
# driver = webdriver.Chrome(chromedriver)
# driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
# driver.maximize_window()
# wait = WebDriverWait(driver, 5)

# numoflines = [12,10,33,8,24,28,6,20,20,6,7,25,690,11,30,35,2,9,6,24,30,4,10,10,13,17,1,4,15,29,10,15,56,63,7,4,1]
# df = pd.read_excel("data.xlsx", index_col=0)
# addition = 0
# Y = 250

# sector = Select(driver.find_element_by_id("sector"))
# #symbol = Select(driver.find_element_by_id("Symbol"))

# with open("output.txt", "w") as myfile:
#     for sec in sector.options[1:]:
#         print(sec)
# #         x = 0
# #         Y = 0
#         sec.click()
#     #     symbol = Select(driver.find_element_by_id("Symbol"))

#     #         symbol.select_by_index(x)
#     #         print(symbol.first_selected_option.text)

#         for x in numoflines:
#             for i in range(x):
#                 symbol = df['Ticker'][addition+i] 
#                 symbol = symbol.split()[0] #picks up symbol
#                 print(symbol)
#     #             sector = Select(driver.find_element_by_id(symbol))
#                 findelement = wait.until(EC.presence_of_element_located((By.ID, symbol)))
#                 findelement.click()

#                 # we do this after thingy has been clicked upon
#                 extract = wait.until(EC.presence_of_element_located((By.ID, "addressbookdata")))

#                 #close the popup
#                 WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//button[@class='close'][@data-dismiss='modal']"))).click()

#                 driver.execute_script("window.scrollBy(0,50);")

# #                 Y += 150

#                 myfile.write(extract.get_attribute('innerText'))

#             addition += x
#             driver.execute_script("window.scrollTo(0,0)")
#             print(addition)

# %%
# PERFECTLY WORKING CODE

# chromedriver = "chromedriver.exe"
# driver = webdriver.Chrome(chromedriver)
# driver.get("https://www.psx.com.pk/psx/resources-and-tools/listings/listed-companies")
# driver.maximize_window()
# wait = WebDriverWait(driver, 5)

# numoflines = [12,10,33,8,24,28,6,20,20,6,7,25,690,11,30,35,2,9,6,24,30,4,10,10,13,17,1,4,15,29,10,15,56,63,7,4,1]
# df = pd.read_excel("data.xlsx", index_col=0)
# addition = 0

# sector = Select(driver.find_element_by_id("sector"))
# #symbol = Select(driver.find_element_by_id("Symbol"))

# with open("output.txt", "w") as myfile:
#     for sec in sector.options[1:]:
#         sec.click()


#         for x in numoflines:
#             for i in range(x):
#                 symbol = df['Ticker'][addition+i] 
#                 symbol = symbol.split()[0] #picks up symbol
#                 print(symbol)
#                 findelement = wait.until(EC.presence_of_element_located((By.ID, symbol)))
#                 findelement.click()

#                 # we do this after thingy has been clicked upon
#                 extract = wait.until(EC.presence_of_element_located((By.ID, "addressbookdata")))

#                 #close the popup
#                 WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//button[@class='close'][@data-dismiss='modal']"))).click()

#                 driver.execute_script("window.scrollBy(0,50);")

#                 myfile.write(extract.get_attribute('innerText'))

#             addition += x
#             driver.execute_script("window.scrollTo(0,0)")
#             print(addition)
